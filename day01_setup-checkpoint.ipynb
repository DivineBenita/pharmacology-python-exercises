# %% [markdown]
# #My Computational Biomedical Research
# **Name:** Divine Benita Esabu
# **Degree:** Pharm D
# **Goal:** MSc Computational Biomedical Science - UCL
#
# ## Why I am doing this
# I am building computational skills to become a globally competitive researcher in computational pharmacology and drug discovery
