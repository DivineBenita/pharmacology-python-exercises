# %%
patient_age = 35
tablet_count = 12
days_of_treatment = 7

print(patient_age)
print(type(patient_age))
# Out:
# 35
# <class 'int'>

# %%
weight_kg = 68.5
dose_mg = 500.0
bmi = 24.7
temperature = 37.2

print(weight_kg)
print(type(weight_kg))
# Out:
# 68.5
# <class 'float'>

# %%
drug_name = "paracetamol"
patient_name = "Adaeze"
diagnosis = "Type 2 diabetes"
route = "oral"

print(drug_name)
print(type(drug_name))
# Out:
# paracetamol
# <class 'str'>

# %%
requires_monitoring = True
is_pregnant = False
has_allergies = True
completed_course = False

print(requires_monitoring)
print(type(requires_monitoring))
# Out:
# True
# <class 'bool'>

# %%
# Converting between types
age_as_text = "35"
print(type(age_as_text))

age_as_number = int(age_as_text)
print(type(age_as_number))
print(age_as_number + 5)

dose_as_text = "500.0"
dose_as_number = float(dose_as_text)
print(dose_as_number * 2)

age_back_to_text = str(age_as_number)
print(type(age_back_to_text))
print("Patient age: " + age_back_to_text)
# Out:
# <class 'str'>
# <class 'int'>
# 40
# 1000.0
# <class 'str'>
# Patient age: 35

# %%
# The clunky way
print("Patient " + patient_name + " weighs " + str(weight_kg) + "kg")
# Out:
# Patient Adaeze weighs 68.5kg

# %%
print(f"Patient {patient_name} weighs {weight_kg} kg")
# Out:
# Patient Adaeze weighs 68.5 kg

# %%
# Complete patient record using all four types
patient_name = "Ngozi"
patient_age = 58
weight_kg = 74.2
diagnosis = "Uncomplicated Malaria"
drug = "Tab. Artemether/Lumefantrine"
dose_artemether_mg = 80
dose_lumefantrine_mg = 480
frequency = 2
requires_follow_up = True

# Clinical summary using f-strings
print("=" * 45)
print("PATIENT MEDICATION SUMMARY")
print("=" * 45)
print(f"Name:              {patient_name}")
print(f"Age:               {patient_age} years")
print(f"Weight:            {weight_kg}kg")
print(f"Diagnosis:         {diagnosis}")
print(f"Drug:              {drug.title()}")
print(f"Artemether Dose:   {dose_artemether_mg}mg")
print(f"Lumefantrine Dose: {dose_lumefantrine_mg}mg")
print(f"Frequency:         {frequency}x daily")
print(f"Follow-up:         {requires_follow_up}")
print("=" * 45)

# Simple calculation
daily_total_of_Artemether = dose_artemether_mg * frequency
daily_total_of_Lumefantrine = dose_lumefantrine_mg * frequency
weekly_total_of_Artemether = daily_total_of_Artemether * 3
weekly_total_of_Lumefantrine = daily_total_of_Lumefantrine * 3
print(f"Daily total of Artemether:     {daily_total_of_Artemether}mg")
print(f"Daily total of Lumefantrine:   {daily_total_of_Lumefantrine}mg")

print(f"Weekly total of Artemether:    {weekly_total_of_Artemether}mg")
print(f"Weekly total of Lumefantrine:  {weekly_total_of_Lumefantrine}mg")
# Out:
# ...
# PATIENT MEDICATION SUMMARY
# ...
# Name:              Ngozi
# Age:               58 years
# Weight:            74.2kg
# Diagnosis:         Uncomplicated Malaria
# Drug:              Tab. Artemether/Lumefantrine
# Artemether Dose:   80mg
# Lumefantrine Dose: 480mg
# Frequency:         2x daily
# Follow-up:         True
# ...
# Daily total of Artemether:     160mg
# Daily total of Lumefantrine:   960mg
# Weekly total of Artemether:    480mg
# Weekly total of Lumefantrine:  2880mg

# %% [markdown]
# ## Day 8 Complete — 12 June 2026
# **- Concepts:** int, float, str, bool, type conversion, f-strings.
#
# **- One thing that surprised me:** combination drugs need multiple variables, not one.
#
# **- One thing I want to understand better:** string methods like .title() and .capitalize().
