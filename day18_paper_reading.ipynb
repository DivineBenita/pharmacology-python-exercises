# %% [markdown]
# Paper title: Machine Learning in Drug Discovery: A Review
# Authors: Suresh Dara, Swetha Dhamercherla, Surender Singh Jadav, CH Madhu Babu, Mohamed Jawed Ahsan.
# Journal: Artificial Intelligence Review
# Year: 2021
#
# What is this paper about? This is about the employment of ML tools and techniques at every stage of drug discovery and development.
# What is the central finding or argument? ML techniques can be employed to cater for the inadequacy in drug discovery.
# What data or methods are mentioned in the abstract? QSAR analysis, hit discoveries.

# %% [markdown]
# ## 100-word summary
